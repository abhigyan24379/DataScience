# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
from tensorflow.keras.datasets import mnist, cifar10

# %%
(x_train,y_train),(x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
print(f"MINIST: {x_train.shape}, test {x_test.shape}")
# Out:
# MINIST: (60000, 28, 28), test (10000, 28, 28)

# %%
(x_train_cifar, y_train_cifar), (x_test_cifar , y_test_cifar) = cifar10.load_data()
print(f"CIFAR-10 Dataset: train- {x_train_cifar},  test- {x_test_cifar}")
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 218s 1us/step
# CIFAR-10 Dataset: train- [[[[ 59  62  63]
#    [ 43  46  45]
#    [ 50  48  43]
#    ...
#    [158 132 108]
#    [152 125 102]
#    [148 124 103]]
#
#   [[ 16  20  20]
#    [  0   0   0]
#    [ 18   8   0]
#    ...
#    [123  88  55]
#    [119  83  50]
#    [122  87  57]]
#
#   [[ 25  24  21]
#    [ 16   7   0]
#    [ 49  27   8]
#    ...
#    [118  84  50]
#    [120  84  50]
#    [109  73  42]]
#
#   ...
#
#   [[208 170  96]
#    [201 153  34]
#    [198 161  26]
#    ...
#    [160 133  70]
#    [ 56  31   7]
#    [ 53  34  20]]
#
#   [[180 139  96]
#    [173 123  42]
#    [186 144  30]
#    ...
#    [184 148  94]
#    [ 97  62  34]
#    [ 83  53  34]]
#
#   [[177 144 116]
#    [168 129  94]
#    [179 142  87]
#    ...
#    [216 184 140]
#    [151 118  84]
#    [123  92  72]]]
#
#
#  [[[154 177 187]
#    [126 137 136]
#    [105 104  95]
#    ...
#    [ 91  95  71]
#    [ 87  90  71]
#    [ 79  81  70]]
#
#   [[140 160 169]
# ...

# %%
import tensorflow as tf 
layer = tf.keras.layers.Dense(units=10, activation='relu')
print(f"Tensorflow layer: {layer}")
# Out:
# Tensorflow layer: <Dense name=dense, built=False>

# %%
import torch
import torch.nn as nn

# %%
# defining a basic dense layer 
layer = nn.Linear(in_features=10, out_features=5)
print(f"pytorch layer: {layer}")
# Out:
# pytorch layer: Linear(in_features=10, out_features=5, bias=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title(f"Mnist label: {y_train[0]}")
plt.show()

# %%
plt.imshow(x_train_cifar[0])
plt.title("cifar")
plt.show()
